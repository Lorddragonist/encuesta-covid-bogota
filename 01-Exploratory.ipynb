# %% [markdown]
# # Análisis exploratorio de "Encuesta de percepción sobre salud mental durante la cuarentena por COVID - 19 en Bogotá"
# Podrás descargar este dataset en https://www.datos.gov.co/dataset/Encuesta-de-percepci-n-sobre-salud-mental-durante-/2pwg-teum/about_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap
import missingno as msn
from column_dictionary import questions
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Esta es una extensión de Pandas que se encuentra en esta misma carpeta para tratar los datos faltantes.

# %%
# %run pandas-missing-extension.ipynb

# %% [markdown]
# Procesanmdo el csv que contiene el Dataset, este se encuentra separado por ";"

# %%
df = pd.read_csv(
    "./data/base_saludmental.csv",
    sep=";"
)

# %% [markdown]
# Mostrando primeros 5 registros del Dataset

# %%
df.head()
# Out:
#   Marca temporal  \
# 0    44018,34521
# 1    44018,34595
# 2    44018,34611
# 3    44018,35482
# 4    44018,35899
#
#   1. Para empezar, nos gustaría saber qué tanto confía en la gente de su manzana o vecindario. Podría decir que entre sus vecinos usted confía en:  \
# 0                                         La mayoría
# 1                                            Algunos
# 2                                            Algunos
# 3                                         La mayoría
# 4                                         La mayoría
#
#   2. ¿Durante el mes pasado, qué tan seguido habló con sus vecinos?  \
# 0                                               Nada
# 1                                               Nada
# 2                          Algunas veces a la semana
# 3                          Algunas veces a la semana
# 4                               Algunas veces al mes
#
#   3. ¿En un mes normal, antes de que comenzara el confinamiento en Bogotá a causa del COVID-19, con qué frecuencia hablaba con sus vecinos?  \
# 0                               Algunas veces al mes
# 1                                               Nada
# 2                          Algunas veces a la semana
# 3                          Algunas veces a la semana
# 4                               Algunas veces al mes
#
#   4. ¿Durante el mes pasado, qué tan seguido habló con sus amigos y familiares (incluyendo medios electrónicos como chats, redes sociales, llamadas telefónicas, videollamadas, etc.)?  \
# 0                                Casi todos los días
# 1                                Casi todos los días
# 2                                Casi todos los días
# 3                                Casi todos los días
# 4                          Algunas veces a la semana
#
#   5. En un mes normal, antes de que comenzara el confinamiento en Bogotá a causa del COVID-19, ¿con qué frecuencia hablaba con sus amigos y familiares (incluyendo medios electrónicos como chats, redes sociales, llamadas telefónicas, videollamadas, etc.)?  \
# 0                          Algunas veces a la semana
# 1                               Algunas veces al mes
# 2                                Casi todos los días
# 3                                Casi todos los días
# 4                          Algunas veces a la semana
#
#   6. El gobierno ha promovido medidas de autocuidado (cuidarse a usted mismo) como el aislamiento social, el uso de tapabocas, el lavado de manos y mantener el distanciamiento físico. En una escala de 1 a 5, donde 1 equivale a "nada" y 5 a "totalmente": [¿Considera que usted ha cumplido con las medidas de autocuidado?]  \
# 0                                       5 Totalmente
# 1                                       5 Totalmente
# 2                                       5 Totalmente
# 3                                       5 Totalmente
# 4                                                  4
#
#   6. El gobierno ha promovido medidas de autocuidado (cuidarse a usted mismo) como el aislamiento social, el uso de tapabocas, el lavado de manos y mantener el distanciamiento físico. En una escala de 1 a 5, donde 1 equivale a "nada" y 5 a "totalmente": [¿Considera que sus familiares han cumplido con las medidas de autocuidado?]  \
# 0                                       5 Totalmente
# 1                                                  4
# 2                                       5 Totalmente
# 3                                                  4
# 4                                                  4
#
#   6. El gobierno ha promovido medidas de autocuidado (cuidarse a usted mismo) como el aislamiento social, el uso de tapabocas, el lavado de manos y mantener el distanciamiento físico. En una escala de 1 a 5, donde 1 equivale a "nada" y 5 a "totalmente": [¿Considera que sus vecinos han cumplido con las medidas de autocuidado?]  \
# 0                                       5 Totalmente
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#   7. Para usted, la estrategia de comunicación y la información presentada por la alcaldía en relación con el COVID-19 hasta este momento ha sido: [Clara]  \
# 0                                                 Sí
# 1                                                 No
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 Sí
#
#    ... 29. ¿Contándose a usted mismo, cuántas personas viven en su hogar?  \
# 0  ...                                             Cuatro
# 1  ...                                                Dos
# 2  ...                                               Tres
# 3  ...                                             Cuatro
# 4  ...                                    Una (vivo solo)
#
#   30. ¿Contándose a usted mismo, y según la edad de cada uno, cuántas personas viven en su hogar? [De 5 años o menos]  \
# 0                                                Una
# 1                                            Ninguna
# 2                                            Ninguna
# 3                                            Ninguna
# 4                                            Ninguna
#
#   30. ¿Contándose a usted mismo, y según la edad de cada uno, cuántas personas viven en su hogar? [Entre 6 y 18 años]  \
# 0                                                Una
# 1                                            Ninguna
# 2                                            Ninguna
# 3                                            Ninguna
# 4                                            Ninguna
#
#   30. ¿Contándose a usted mismo, y según la edad de cada uno, cuántas personas viven en su hogar? [Entre 19 y 64 años]  \
# 0                                                Dos
# 1                                                Una
# 2                                               Tres
# 3                                             Cuatro
# 4                                                Una
#
#   30. ¿Contándose a usted mismo, y según la edad de cada uno, cuántas personas viven en su hogar? [De 65 años o más]  \
# 0                                            Ninguna
# 1                                            Ninguna
# 2                                            Ninguna
# 3                                            Ninguna
# 4                                            Ninguna
#
#   17. ¿Considera que ha tenido la oportunidad de expresarle cómo se siente a otras personas?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 Sí
#
#   16. ¿Durante el último mes, con qué frecuencia ha realizado actividades físicas como bailar o practicar algún deporte?  \
# 0                                        Ninguna vez
# 1                       Menos de una vez a la semana
# 2                         Más de una vez a la semana
# 3                         Más de una vez a la semana
# 4                                Una vez a la semana
#
#   28. ¿En una escala de 1 a 5 donde 1 significa "nada" y 5 significa "mucho", siente que en su casa usted está expuesto a algún tipo de violencia?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#   19. ¿Usted o alguna de las personas con las que vive ha sido diagnósticado con alguna enfermedad de salud mental que requiera tratamiento?  \
# 0                                                 No
# 1                                                 Sí
# 2                                                 No
# 3                                                 Sí
# 4                                                 No
#
#   20. En caso de que la respuesta a la pregunta anterior sea "Sí", ¿ha podido continuar el tratamiento durante el periodo de cuarentena?
# 0                                          No aplica
# 1                                                 Sí
# 2                                          No aplica
# 3                                                 No
# 4                                          No aplica
#
# [5 rows x 55 columns]

# %% [markdown]
# Mostrando dimensiones del dataset

# %%
df.shape
# Out:
# (4998, 55)

# %% [markdown]
# Dado que dejar el encabezado de la pregunta es demasiado largo para ser un nombre de columna, he creado un diccionario en **column_dictionary.py** para representar las preguntas con nombres de variable.

# %%
new_columns = [questions[col_name] for col_name in df.columns]
df. columns = new_columns
df.head()
# Out:
#      timestamp confianza_vecinos frecuencia_habla_vecinos_mes_pasado  \
# 0  44018,34521        La mayoría                                Nada
# 1  44018,34595           Algunos                                Nada
# 2  44018,34611           Algunos           Algunas veces a la semana
# 3  44018,35482        La mayoría           Algunas veces a la semana
# 4  44018,35899        La mayoría                Algunas veces al mes
#
#   frecuencia_habla_vecinos_mes_normal  \
# 0                Algunas veces al mes
# 1                                Nada
# 2           Algunas veces a la semana
# 3           Algunas veces a la semana
# 4                Algunas veces al mes
#
#   frecuencia_habla_amigos_familia_mes_pasado  \
# 0                        Casi todos los días
# 1                        Casi todos los días
# 2                        Casi todos los días
# 3                        Casi todos los días
# 4                  Algunas veces a la semana
#
#   frecuencia_habla_amigos_familia_mes_normal  \
# 0                  Algunas veces a la semana
# 1                       Algunas veces al mes
# 2                        Casi todos los días
# 3                        Casi todos los días
# 4                  Algunas veces a la semana
#
#   cumplimiento_autocuidado_personal cumplimiento_autocuidado_familiares  \
# 0                      5 Totalmente                        5 Totalmente
# 1                      5 Totalmente                                   4
# 2                      5 Totalmente                        5 Totalmente
# 3                      5 Totalmente                                   4
# 4                                 4                                   4
#
#   cumplimiento_autocuidado_vecinos estrategia_comunicacion_clara  ...  \
# 0                     5 Totalmente                            Sí  ...
# 1                                3                            No  ...
# 2                                3                            Sí  ...
# 3                                4                            Sí  ...
# 4                                4                            Sí  ...
#
#   num_personas_hogar num_personas_5_menos num_personas_6_18  \
# 0             Cuatro                  Una               Una
# 1                Dos              Ninguna           Ninguna
# 2               Tres              Ninguna           Ninguna
# 3             Cuatro              Ninguna           Ninguna
# 4    Una (vivo solo)              Ninguna           Ninguna
#
#   num_personas_19_64 num_personas_65_mas oportunidad_expresar_sentimientos  \
# 0                Dos             Ninguna                                Sí
# 1                Una             Ninguna                                Sí
# 2               Tres             Ninguna                                Sí
# 3             Cuatro             Ninguna                                Sí
# 4                Una             Ninguna                                Sí
#
#   frecuencia_actividad_fisica_mes exposicion_violencia_hogar  \
# 0                     Ninguna vez                        1.0
# 1    Menos de una vez a la semana                        1.0
# 2      Más de una vez a la semana                        1.0
# 3      Más de una vez a la semana                        1.0
# 4             Una vez a la semana                        1.0
#
#   diagnostico_salud_mental continuidad_tratamiento_salud_mental
# 0                       No                            No aplica
# 1                       Sí                                   Sí
# 2                       No                            No aplica
# 3                       Sí                                   No
# 4                       No                            No aplica
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Datos faltantes

# %%
df.missing.missing_case_plot()

# %% [markdown]
# Revisión de cuantros valores son faltantes por variable

# %%
missing_values_summary = df.missing.missing_variable_summary()
missing_values_summary = missing_values_summary[missing_values_summary['n_missing'] > 0].reset_index()
missing_values_summary.sort_values('n_missing', ascending=False, inplace=True)
missing_values_summary
# Out:
#     index                                      variable  n_missing  n_cases  \
# 29     54          continuidad_tratamiento_salud_mental        887     4998
# 10     30                       apoyo_pareja_cuarentena        310     4998
# 13     33  apoyo_empleador_entidad_educativa_cuarentena        154     4998
# 16     36            apoyo_gobierno_nacional_cuarentena         84     4998
# 14     34                      apoyo_vecinos_cuarentena         81     4998
# 15     35                     apoyo_alcaldia_cuarentena         74     4998
# 12     32                       apoyo_amigos_cuarentena         59     4998
# 19     39                                    rango_edad         26     4998
# 25     50             oportunidad_expresar_sentimientos         25     4998
# 6      15                sabe_actuar_sospechas_contagio         20     4998
# 26     51               frecuencia_actividad_fisica_mes         19     4998
# 11     31                      apoyo_familia_cuarentena         18     4998
# 20     40                      diagnostico_enfermedades         17     4998
# 9      18                             diagnostico_COVID         14     4998
# 17     37                                          sexo         13     4998
# 7      16                         info_suficiente_COVID         13     4998
# 18     38                                          edad         13     4998
# 23     44   condiciones_vivienda_tranquilidad_comodidad         12     4998
# 27     52                    exposicion_violencia_hogar         12     4998
# 8      17                   info_riesgos_COVID_alcaldia         10     4998
# 2       3           frecuencia_habla_vecinos_mes_normal          9     4998
# 21     41                               nivel_educativo          9     4998
# 3       4    frecuencia_habla_amigos_familia_mes_pasado          8     4998
# 4       5    frecuencia_habla_amigos_familia_mes_normal          6     4998
# 22     43                             situacion_laboral          6     4998
# 28     53                      diagnostico_salud_mental          6     4998
# 1       2           frecuencia_habla_vecinos_mes_pasado          5     4998
# 24     45                            num_personas_hogar          4     4998
# 0       1                             confianza_vecinos          4     4998
# 5      14                          medios_info_alcaldia          1     4998
#
#     pct_missing
# 29    17.747099
# 10     6.202481
# 13     3.081232
# 16     1.680672
# 14     1.620648
# 15     1.480592
# 12     1.180472
# 19     0.520208
# 25     0.500200
# 6      0.400160
# 26     0.380152
# 11     0.360144
# 20     0.340136
# 9      0.280112
# 17     0.260104
# 7      0.260104
# 18     0.260104
# 23     0.240096
# 27     0.240096
# 8      0.200080
# 2      0.180072
# 21     0.180072
# 3      0.160064
# 4      0.120048
# 22     0.120048
# 28     0.120048
# 1      0.100040
# 24     0.080032
# 0      0.080032
# 5      0.020008

# %%
sns.barplot(
    x=missing_values_summary['n_missing'],
    y=missing_values_summary['variable']
)
plt.show()

# %% [markdown]
# Aquí podemos ver que un 17.74% no contestó la variable **continuidad_tratamiento_salud_mental** que corresponde a **20. En caso de que la respuesta a la pregunta anterior sea "Sí", ¿ha podido continuar el tratamiento durante el periodo de cuarentena?**, pero también podemos ver que esta depende de la pregunta anterior **19. ¿Usted o alguna de las personas con las que vive ha sido diagnosticado con alguna enfermedad de salud mental que requiera tratamiento?** el cual solo un 0.12% no respondió esa pregunta, lo que no hace relevante que este 17.74% haya omitido esta pregunta, ya que un 80.92% respondió que no y un 6.12% respondió que no está seguro.

# %%
df['diagnostico_salud_mental'].value_counts(normalize=True) * 100
# Out:
# diagnostico_salud_mental
# No                80.929487
# Sí                12.940705
# No está seguro     6.129808
# Name: proportion, dtype: float64

# %%
variables_missing = missing_values_summary.variable.to_list()

# %%
msn.matrix(df=df[variables_missing])
plt.show()

# %% [markdown]
# ## Funciones Utilities

# %% [markdown]
# Función para devolver el nombre llave del diccionario Questions

# %%
def get_key_from_questions(val):
    for key, value in questions.items():
        if value == val:
            return key
    return None

# %% [markdown]
# Función para mostrar la distribución de una variable

# %%
def show_distribution(col):
    column = list(questions.values())[col]
    question = get_key_from_questions(column)
    
    print(f"\nNombre de variable: {column}",sep='\n')
    
    value_counts = df[column].value_counts(normalize=True).sort_values(ascending=False) * 100
    
    for index, value in value_counts.items():
        print(f'{index}: {value:.2f}%')
    
    plot_data = pd.DataFrame({
        'valores_unicos': value_counts.index,
        'porcentajes': value_counts.values
    })
    
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(x='valores_unicos', y='porcentajes', data=plot_data)
    
    plt.xlabel(column)
    plt.title(textwrap.fill(question, 100))
    
    wrapped_labels = [textwrap.fill(label, 10) for label in plot_data['valores_unicos']]
    ax.set_xticklabels(wrapped_labels, rotation=0)
    
    plt.show()

# %%
show_distribution(1)
# Out:
# Nombre de variable: confianza_vecinos
# Algunos: 48.36%
# La mayoría: 29.32%
# Ninguno: 18.68%
# Todos: 3.64%

# %%
show_distribution(2)
# Out:
# Nombre de variable: frecuencia_habla_vecinos_mes_pasado
# Nada: 38.03%
# Algunas veces al mes: 28.28%
# Una vez: 19.59%
# Algunas veces a la semana: 11.30%
# Casi todos los días: 1.50%
# No está seguro: 1.30%

# %%
show_distribution(3)
# Out:
# Nombre de variable: frecuencia_habla_vecinos_mes_normal
# Algunas veces al mes: 33.41%
# Algunas veces a la semana: 24.31%
# Nada: 20.69%
# Una vez: 11.16%
# Casi todos los días: 9.02%
# No está seguro: 1.40%

# %%
show_distribution(4)
# Out:
# Nombre de variable: frecuencia_habla_amigos_familia_mes_pasado
# Casi todos los días: 55.41%
# Algunas veces a la semana: 30.04%
# Algunas veces al mes: 11.96%
# Una vez: 1.34%
# Nada: 1.04%
# No está seguro: 0.20%

# %%
show_distribution(5)
# Out:
# Nombre de variable: frecuencia_habla_amigos_familia_mes_normal
# Casi todos los días: 58.09%
# Algunas veces a la semana: 30.51%
# Algunas veces al mes: 9.90%
# Una vez: 1.02%
# Nada: 0.32%
# No está seguro: 0.16%

# %%
show_distribution(6)
# Out:
# Nombre de variable: cumplimiento_autocuidado_personal
# 5 Totalmente: 65.11%
# 4: 24.19%
# 3: 8.56%
# 2: 1.74%
# 1 Nada: 0.40%

# %%
show_distribution(7)
# Out:
# Nombre de variable: cumplimiento_autocuidado_familiares
# 5 Totalmente: 49.12%
# 4: 33.91%
# 3: 13.05%
# 2: 3.40%
# 1 Nada: 0.52%

# %%
show_distribution(8)
# Out:
# Nombre de variable: cumplimiento_autocuidado_vecinos
# 3: 34.17%
# 4: 29.45%
# 2: 19.55%
# 5 Totalmente: 10.04%
# 1 Nada: 6.78%

# %%
show_distribution(9)
# Out:
# Nombre de variable: estrategia_comunicacion_clara
# Sí: 70.61%
# No: 23.03%
# No sabe: 6.36%

# %%
show_distribution(10)
# Out:
# Nombre de variable: estrategia_comunicacion_suficiente
# Sí: 56.24%
# No: 32.97%
# No sabe: 10.78%

# %%
show_distribution(11)
# Out:
# Nombre de variable: estrategia_comunicacion_veridica
# Sí: 57.00%
# No sabe: 24.07%
# No: 18.93%

# %%
show_distribution(12)
# Out:
# Nombre de variable: estrategia_comunicacion_oportuna
# Sí: 73.73%
# No: 18.85%
# No sabe: 7.42%

# %%
show_distribution(13)
# Out:
# Nombre de variable: estrategia_comunicacion_contradictoria
# No: 56.24%
# Sí: 32.01%
# No sabe: 11.74%

# %%
column = list(questions.values())[14]
get_key_from_questions(column)
# Out:
# '8. ¿Por qué medio o medios se entera usted de las decisiones tomadas por la Alcaldía frente al manejo del COVID-19? Puede marcar varias opciones'

# %%
show_distribution(15)
# Out:
# Nombre de variable: sabe_actuar_sospechas_contagio
# Sí: 85.24%
# No: 14.76%

# %%
show_distribution(16)
# Out:
# Nombre de variable: info_suficiente_COVID
# Sí: 82.77%
# No: 17.23%

# %%
show_distribution(17)
# Out:
# Nombre de variable: info_riesgos_COVID_alcaldia
# Precisa: 75.12%
# Minimizada: 15.22%
# Exagerada: 9.66%

# %%
show_distribution(18)
# Out:
# Nombre de variable: diagnostico_COVID
# No: 76.77%
# Sí: 23.23%

# %%
show_distribution(19)
# Out:
# Nombre de variable: ansiedad_cuarentena
# Un poco más que antes: 32.21%
# Mucho más que antes: 27.25%
# Igual que antes: 21.83%
# Mucho menos que antes: 10.14%
# Un poco menos que antes: 8.56%

# %%
show_distribution(20)
# Out:
# Nombre de variable: depresion_cuarentena
# Un poco más que antes: 31.63%
# Igual que antes: 26.39%
# Mucho más que antes: 20.61%
# Mucho menos que antes: 12.14%
# Un poco menos que antes: 9.22%

# %%
show_distribution(21)
# Out:
# Nombre de variable: tranquilidad_cuarentena
# Un poco menos que antes: 32.77%
# Mucho menos que antes: 27.39%
# Igual que antes: 24.41%
# Un poco más que antes: 8.36%
# Mucho más que antes: 7.06%

# %%
show_distribution(22)
# Out:
# Nombre de variable: cercania_convive_cuarentena
# Mucho más que antes: 30.33%
# Igual que antes: 29.89%
# Un poco más que antes: 24.33%
# Mucho menos que antes: 8.48%
# Un poco menos que antes: 6.96%

# %%
show_distribution(23)
# Out:
# Nombre de variable: interes_placer_cuarentena
# Igual que antes: 38.76%
# Un poco menos que antes: 23.49%
# Un poco más que antes: 14.59%
# Mucho menos que antes: 12.55%
# Mucho más que antes: 10.62%

# %%
show_distribution(24)
# Out:
# Nombre de variable: problemas_dormir_cuarentena
# Igual que antes: 30.41%
# Un poco más que antes: 25.95%
# Mucho más que antes: 23.11%
# Mucho menos que antes: 11.64%
# Un poco menos que antes: 8.88%

# %%
show_distribution(25)
# Out:
# Nombre de variable: desacuerdos_convive_cuarentena
# Igual que antes: 39.94%
# Un poco más que antes: 20.09%
# Mucho menos que antes: 17.83%
# Un poco menos que antes: 14.29%
# Mucho más que antes: 7.86%

# %%
show_distribution(26)
# Out:
# Nombre de variable: necesidad_alcohol_cuarentena
# No consumo: 43.84%
# Igual que antes: 22.89%
# Mucho menos que antes: 16.65%
# Un poco más que antes: 7.46%
# Un poco menos que antes: 6.56%
# Mucho más que antes: 2.60%

# %%
show_distribution(27)
# Out:
# Nombre de variable: necesidad_fumar_cuarentena
# No consumo: 63.51%
# Mucho menos que antes: 14.49%
# Igual que antes: 12.30%
# Un poco más que antes: 3.80%
# Mucho más que antes: 3.64%
# Un poco menos que antes: 2.26%

# %%
show_distribution(28)
# Out:
# Nombre de variable: necesidad_sustancias_psicoactivas_cuarentena
# No consumo: 70.19%
# Mucho menos que antes: 14.65%
# Igual que antes: 10.82%
# Un poco más que antes: 1.76%
# Mucho más que antes: 1.44%
# Un poco menos que antes: 1.14%

# %%
show_distribution(30)
# Out:
# Nombre de variable: apoyo_pareja_cuarentena
# 5 Todo el que necesito: 50.92%
# 1 Nada: 22.10%
# 4: 15.21%
# 3: 8.72%
# 2: 3.05%

# %%
show_distribution(31)
# Out:
# Nombre de variable: apoyo_familia_cuarentena
# 5 Todo el que necesito: 60.36%
# 4: 22.03%
# 3: 11.53%
# 2: 3.76%
# 1 Nada: 2.33%

# %%
show_distribution(32)
# Out:
# Nombre de variable: apoyo_amigos_cuarentena
# 4: 28.69%
# 5 Todo el que necesito: 26.36%
# 3: 25.23%
# 2: 10.45%
# 1 Nada: 9.27%

# %%
show_distribution(33)
# Out:
# Nombre de variable: apoyo_empleador_entidad_educativa_cuarentena
# 5 Todo el que necesito: 28.76%
# 4: 25.37%
# 3: 18.58%
# 1 Nada: 17.49%
# 2: 9.81%

# %%
show_distribution(34)
# Out:
# Nombre de variable: apoyo_vecinos_cuarentena
# 1 Nada: 46.29%
# 3: 20.64%
# 2: 16.70%
# 4: 10.96%
# 5 Todo el que necesito: 5.41%

# %%
show_distribution(35)
# Out:
# Nombre de variable: apoyo_alcaldia_cuarentena
# 1 Nada: 31.42%
# 3: 23.72%
# 4: 19.70%
# 2: 13.71%
# 5 Todo el que necesito: 11.45%

# %%
show_distribution(36)
# Out:
# Nombre de variable: apoyo_gobierno_nacional_cuarentena
# 1 Nada: 44.93%
# 3: 19.72%
# 2: 18.07%
# 4: 11.17%
# 5 Todo el que necesito: 6.11%

# %%
show_distribution(37)
# Out:
# Nombre de variable: sexo
# Mujer: 64.91%
# Hombre: 34.22%
# Prefiero no decirlo: 0.58%
# No binario: 0.28%

# %%
show_distribution(39)
# Out:
# Nombre de variable: rango_edad
# De 46 a 59: 32.60%
# De 36 a 45: 24.66%
# De 26 a 35: 22.18%
# De 15 a 25: 12.11%
# Mayor de 60: 8.45%

# %%
show_distribution(40)
# Out:
# Nombre de variable: diagnostico_enfermedades
# Sí: 59.51%
# No: 37.46%
# No está seguro: 3.03%

# %%
show_distribution(41)
# Out:
# Nombre de variable: nivel_educativo
# Título de posgrado: 41.37%
# Título universitario: 27.16%
# Título técnico o tecnológico: 17.84%
# Secundaria completa: 10.18%
# Secundaria incompleta: 2.57%
# Primaria completa: 0.62%
# Primaria incompleta: 0.26%

# %%
df['localidad_residencia'].value_counts(normalize=True) * 100
# Out:
# localidad_residencia
# Suba                   14.025610
# Kennedy                12.244898
# Engativá               12.144858
# Usaquén                 8.963585
# Fontibón                8.043217
# Teusaquillo             6.022409
# No reside en Bogotá     5.002001
# Puente Aranda           4.201681
# Ciudad Bolívar          3.701481
# San Cristóbal           3.601441
# Bosa                    3.601441
# Chapinero               3.281313
# Barrios Unidos          3.141257
# Rafael Uribe Uribe      2.821128
# Tunjuelito              2.340936
# Usme                    1.960784
# Santa Fe                1.800720
# Antonio Nariño          1.160464
# Los Mártires            1.100440
# La Candelaria           0.560224
# No sabe                 0.220088
# Sumapaz                 0.060024
# Name: proportion, dtype: float64

# %%
show_distribution(44)
# Out:
# Nombre de variable: condiciones_vivienda_tranquilidad_comodidad
# Sí: 90.43%
# No: 9.57%

# %%
show_distribution(45)
# Out:
# Nombre de variable: num_personas_hogar
# Tres: 27.13%
# Cuatro: 24.03%
# Dos: 19.78%
# Cinco: 11.79%
# Seis o más: 10.75%
# Una (vivo solo): 6.51%

# %%
show_distribution(46)
# Out:
# Nombre de variable: num_personas_5_menos
# Ninguna: 83.39%
# Una: 13.17%
# Dos: 2.28%
# Tres: 0.54%
# Cuatro: 0.28%
# Seis o más: 0.20%
# Cinco: 0.14%

# %%
show_distribution(47)
# Out:
# Nombre de variable: num_personas_6_18
# Ninguna: 60.66%
# Una: 26.69%
# Dos: 9.58%
# Tres: 2.22%
# Cuatro: 0.44%
# Seis o más: 0.30%
# Cinco: 0.10%

# %%
show_distribution(48)
# Out:
# Nombre de variable: num_personas_19_64
# Dos: 41.18%
# Tres: 22.33%
# Una: 14.79%
# Cuatro: 11.72%
# Cinco: 3.94%
# Ninguna: 3.04%
# Seis o más: 3.00%

# %%
show_distribution(49)
# Out:
# Nombre de variable: num_personas_65_mas
# Ninguna: 75.77%
# Una: 15.45%
# Dos: 6.94%
# Tres: 0.76%
# Seis o más: 0.46%
# Cuatro: 0.44%
# Cinco: 0.18%

# %%
show_distribution(50)
# Out:
# Nombre de variable: oportunidad_expresar_sentimientos
# Sí: 72.97%
# No: 27.03%

# %%
show_distribution(51)
# Out:
# Nombre de variable: frecuencia_actividad_fisica_mes
# Más de una vez a la semana: 31.03%
# Ninguna vez: 30.79%
# Menos de una vez a la semana: 20.04%
# Una vez a la semana: 18.14%

# %%
df['exposicion_violencia_hogar'].value_counts(normalize=True) * 100
# Out:
# exposicion_violencia_hogar
# 1.0    79.342158
# 2.0    10.569595
# 3.0     4.993983
# 4.0     3.389491
# 5.0     1.704773
# Name: proportion, dtype: float64

# %%
show_distribution(53)
# Out:
# Nombre de variable: diagnostico_salud_mental
# No: 80.93%
# Sí: 12.94%
# No está seguro: 6.13%

# %%
show_distribution(54)
# Out:
# Nombre de variable: continuidad_tratamiento_salud_mental
# No aplica: 80.93%
# No: 8.10%
# Sí: 7.49%
# No está seguro: 3.48%
